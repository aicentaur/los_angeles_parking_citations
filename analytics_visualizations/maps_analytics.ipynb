# %%
# import dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import os
import csv
from pandas import DataFrame
import pandas as pd
import numpy as np

# %% [markdown]
# # Graph 1 | Citations per Year/Month

# %%
# load data
path = 'visualization_data/graph_1_citations_by_yyyy.csv'
graph_1 = pd.read_csv(path, sep=",")

# plot data
graph_1.plot.bar(x='Year', y='counts', label = "Parking Citations")

#format plot
plt.title("Parking Citations by Year", fontdict = {"fontsize": 14, "fontweight": "bold"})
plt.xlabel("Years", fontdict = {"fontsize": 9, "fontweight": "bold"})
plt.ylabel("Number of Parking Citations (in Millions)", fontdict = {"fontsize": 9, "fontweight": "bold"})

# Save the figure
plt.tight_layout()
plt.savefig("graphs/citations_by_year.png")

# Show the figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Map Visualization 1 | Areas with Highest Number of Tickets

# %%
# load data and create "tuple_coordinates" column
map_1 = pd.read_csv('visualization_data/map_1_citations_areas.csv')
map_1['tuple_coordinates'] = list(zip(map_1.longitude, map_1.latitude))
map_1.head(3)
# Out:
#                location   latitude   longitude  counts  \
# 0     1301 ELECTRIC AVE  33.991691 -118.467910    8330
# 1  1600 IRVING TABOR CT  33.990358 -118.463691    6318
# 2    101 LARCHMONT BL N  34.073023 -118.323530    4591
#
#                           tuple_coordinates
# 0  (-118.46790999864865, 33.99169100266038)
# 1  (-118.4636909969813, 33.990358001930325)
# 2  (-118.32353000125336, 34.07302300105831)

# %%
# put "tuple_coordinates" column into list
list_tuple_1 = map_1['tuple_coordinates'].tolist()
print(f"Total number of records:{len(list_tuple_1)}")
# Out:
# Total number of records:18152

# %%
from ipyleaflet import Map, Marker, MarkerCluster, FullScreenControl

m = Map(center=(34.0522, -118.2437), zoom=10)


markerList = []
for i in list_tuple_1:
    marker = Marker(location=(i[1], i[0]))
    markerList.append(marker)
    

marker_cluster = MarkerCluster(
markers=(markerList))

m.add_layer(marker_cluster);
m.add_control(FullScreenControl())

m
# Out:
# /Users/pavelaltukhov/anaconda3/envs/meters_ml_3.6/lib/python3.6/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /Users/pavelaltukhov/anaconda3/envs/meters_ml_3.6/lib/python3.6/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %% [markdown]
# # Graph 2 | Top 10 Parking Violations

# %%
# load data
path = 'visualization_data/graph_2_top10_violations.csv'
graph_2 = pd.read_csv(path, sep=",")

# plot data
graph_2[0:10].plot.bar(x='violation_description', y='counts', label = "Parking Citations")

#format plot
plt.title("Top 10 Parking Violations", fontdict = {"fontsize": 14, "fontweight": "bold"})
plt.xlabel("Violation Type", fontdict = {"fontsize": 9, "fontweight": "bold"})
plt.ylabel("Number of Citations (in Millions)", fontdict = {"fontsize": 9, "fontweight": "bold"})

# Save the figure
plt.tight_layout()
plt.savefig("graphs/top_10_violations.png")

# Show the figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Graph 3 | Parking Tickets Revenue

# %%
# load data
path = 'visualization_data/graph_3_revenue_by_yyyy.csv'
graph_3 = pd.read_csv(path, sep=",")

# plot data
graph_3.plot.bar(x='Year', y='revenue', label = "Revenue")

#format plot
plt.title("Parking Citations Revenue", fontdict = {"fontsize": 14, "fontweight": "bold"})
plt.xlabel("Year", fontdict = {"fontsize": 9, "fontweight": "bold"})
plt.ylabel("Revenue (in Millions)", fontdict = {"fontsize": 9, "fontweight": "bold"})

# Save the figure
plt.tight_layout()
plt.savefig("graphs/revenue_by_year.png")

# Show the figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Graph 4 | Top 10 Revenue by Violation Type

# %%
# load data
path = 'visualization_data/graph_5_revenue_by_violation.csv'
graph_4 = pd.read_csv(path, sep=",")

# plot data
graph_4[0:10].plot.bar(x='violation_description', y='counts', label = "Parking Citations")

#format plot
plt.title("Top 10 Revenue by Violation Type", fontdict = {"fontsize": 14, "fontweight": "bold"})
plt.xlabel("Violation Type", fontdict = {"fontsize": 9, "fontweight": "bold"})
plt.ylabel("Revenue (in Millions)", fontdict = {"fontsize": 9, "fontweight": "bold"})

# Save the figure
plt.tight_layout()
plt.savefig("graphs/top_10_revenue_violations.png")

# Show the figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Map Visualization 2 | Areas with Highest Amount of Revenue

# %%
# load data and create "tuple_coordinates" column
map_2 = pd.read_csv('visualization_data/map_2_revenue_areas.csv')
map_2['tuple_coordinates'] = list(zip(map_2.longitude, map_2.latitude))
map_2.head(3)
# Out:
#     latitude   longitude              location   revenue  \
# 0  33.991691 -118.467910     1301 ELECTRIC AVE  424368.0
# 1  33.990358 -118.463691  1600 IRVING TABOR CT  329175.0
# 2  34.073023 -118.323530    101 LARCHMONT BL N  266490.0
#
#                           tuple_coordinates
# 0  (-118.46790999864865, 33.99169100266038)
# 1  (-118.4636909969813, 33.990358001930325)
# 2  (-118.32353000125336, 34.07302300105831)

# %%
# put "tuple_coordinates" column into list
list_tuple_2 = map_2['tuple_coordinates'].tolist()
print(f"Total number of records:{len(list_tuple_2)}")
# Out:
# Total number of records:32114

# %%
from ipyleaflet import Map, Marker, MarkerCluster, FullScreenControl

m = Map(center=(34.0522, -118.2437), zoom=10)


markerList = []
for i in list_tuple_2:
    marker = Marker(location=(i[1], i[0]))
    markerList.append(marker)
    

marker_cluster = MarkerCluster(
markers=(markerList))

m.add_layer(marker_cluster);
m.add_control(FullScreenControl())

m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %% [markdown]
# # Graph 5 | Fine Amount Distribution

# %% [markdown]
# > The cheapest fine in the dataset is `$10` (display of tabs).<br>
# There are two most expensive parking citations issued in the dataset:<br>
#     `$505` (5 tickets total, with no violation type)<br>
#     `$363` (disabled and handicap related violations)

# %%
# load data
path = 'visualization_data/graph_4_fines_distribution.csv'
graph_4 = pd.read_csv(path, sep=",")

# plot data
graph_4.plot.hist()

#format plot
plt.title("Fine Amount Distribution", fontdict = {"fontsize": 14, "fontweight": "bold"})
plt.xlabel("Fine Amount", fontdict = {"fontsize": 9, "fontweight": "bold"})
plt.ylabel("Number of Citations (in Millions)", fontdict = {"fontsize": 9, "fontweight": "bold"})

# Save the figure
plt.tight_layout()
plt.savefig("graphs/revenue_by_year.png")

# Show the figure
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Map Visualization 3  |   Meters Inventory

# %%
# load data and create "tuple_coordinates" column
map_3 = pd.read_csv('../data_collection_munging/meters_inventory/meters_inventory.csv')
map_3['tuple_coordinates'] = list(zip(map_3.longitude, map_3.latitude))
map_3.head(3)
# Out:
#             address   latitude   longitude    meter_type parking_policy  \
# 0      501 UNION DR  34.057219 -118.268751  Single-Space  8A-6P Mon-Sat
# 1   12200 VENICE BL  34.004300 -118.432007  Single-Space  8A-8P Mon-Sat
# 2  2000 COLORADO BL  34.139067 -118.210994  Single-Space  8A-8P Mon-Sat
#
#    policy_complexity rate_range rate_type meter_id street_cleaning  \
# 0                 13      $1.00      FLAT    WU150      12P-3P Mon
# 1                 13      $1.00      FLAT    MV161             NaN
# 2                 13      $1.00      FLAT    ER138             NaN
#
#    park_limit         tuple_coordinates
# 0         2.0  (-118.268751, 34.057219)
# 1         2.0    (-118.432007, 34.0043)
# 2         2.0  (-118.210994, 34.139067)

# %%
# put "tuple_coordinates" column into list
list_tuple_3 = map_3['tuple_coordinates'].tolist()
print(f"Total number of records:{len(list_tuple_3)}")
# Out:
# Total number of records:33989

# %%
from ipyleaflet import Map, Marker, MarkerCluster, FullScreenControl

m = Map(center=(34.0522, -118.2437), zoom=10)


markerList = []
for i in list_tuple_3:
    marker = Marker(location=(i[1], i[0]))
    markerList.append(marker)
    

marker_cluster = MarkerCluster(
markers=(markerList))

m.add_layer(marker_cluster);
m.add_control(FullScreenControl())

m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
